# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 200

# %%
img = cv2.imread("./images/faces1.jpg")

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import dlib

# %%
hog_face_detector = dlib.get_frontal_face_detector()

# %%
# 检测人脸
# scale 类似hara的scaleFactor
detections = hog_face_detector(img, 1)

# %%
detections
# Out:
# rectangles[[(941, 511) (1096, 666)], [(239, 526) (368, 655)], [(1154, 283) (1262, 390)], [(1615, 168) (1744, 297)], [(282, 271) (390, 378)]]

# %%
for item in detections:
    x = item.left()
    y = item.top()
    r = item.right()
    b = item.bottom()
    cv2.rectangle(img, (x, y), (r, b), (0, 255, 0), 5)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
